# %% [markdown]
# <a href="https://colab.research.google.com/github/SmittyB00p/7K6l06Ibrll2Q4f5/blob/main/Sesame_Fine_Tune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sesame Fine-Tuning
#
# https://blog.speechmatics.com/sesame-finetune#2-data-set-up-and-pre-tokenization
#
# https://github.com/knottwill/sesame-finetune

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !git clone https://github.com/knottwill/sesame-finetune.git
# !git install https://github.com/knottwill/sesame-finetune.git
# %cd sesame-finetune
# !python3.10 -m venv .venv
# !source .venv/bin/activate
# !pip install -r requirements.txt

# %%
os.getcwd()
# Out:
# '/content/sesame-finetune'

# %%
# %%capture
# !git clone https://github.com/SesameAILabs/csm.git
# !git install https://github.com/SesameAILabs/csm.git ~/csm
# %cd csm
# !python3.10 -m venv .venv
# !source .venv/bin/activate
# !pip install -r requirements.txt
# !git checkout 836f886515f0dec02c22ed2316cc78904bdc0f36
# %cd -

# %%
# !cp .env.example .env

# %%
os.environ['CSM_REPO_PATH'] = 'content/sesame-fintune/csm'

# %%
os.environ['PYTORCH_CUDA_ALLOC_CONF']='expandable_segments:True'

# %%
os.environ
# Out:
# environ{'SHELL': '/bin/bash',
#         'NV_LIBCUBLAS_VERSION': '12.5.3.2-1',
#         'NVIDIA_VISIBLE_DEVICES': 'all',
#         'COLAB_JUPYTER_TRANSPORT': 'ipc',
#         'NV_NVML_DEV_VERSION': '12.5.82-1',
#         'NV_CUDNN_PACKAGE_NAME': 'libcudnn9-cuda-12',
#         'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events',
#         'NV_LIBNCCL_DEV_PACKAGE': 'libnccl-dev=2.22.3-1+cuda12.5',
#         'NV_LIBNCCL_DEV_PACKAGE_VERSION': '2.22.3-1',
#         'VM_GCE_METADATA_HOST': '169.254.169.253',
#         'MODEL_PROXY_HOST': 'https://mp.kaggle.net',
#         'HOSTNAME': 'c821646f045c',
#         'LANGUAGE': 'en_US',
#         'TBE_RUNTIME_ADDR': '172.28.0.1:8011',
#         'COLAB_TPU_1VM': '',
#         'GCE_METADATA_TIMEOUT': '3',
# ...

# %%
from google.colab import userdata
# print(f"Hugging Face API Key: {userdata.get('HF_TOKEN')}\n") ## make sure this token is your own token from Hugging Face
# print(f"WandB API Key: {userdata.get('WANDB_API_KEY')}") ## make sure this token is your own token from Weights & Bias

# %%
os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')
os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')

# %%
from huggingface_hub import notebook_login, login
# notebook_login()
login()

# %%
# !huggingface-cli whoami
# Out:
# SmittyB00p

# %%
# !python pretokenize.py --train_data ../drive/MyDrive/project_4/train_metadata/train.json --val_data ../drive/MyDrive/project_4/test_metadata/test.json --output ../drive/MyDrive/project_4/data/tokens.hdf5

# %%
os.getcwd()
# Out:
# '/content/sesame-finetune'

# %%
from IPython.display import Audio

Audio(f"../drive/MyDrive/project_4/audio_files/bible_verses_489.mp3", autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python train.py --data ../drive/MyDrive/project_4/data/tokens.hdf5 --n_epochs 50 --gen_every 500 --gen_sentence "Midway through the journey of life I found I had strayed from the path within the dark wood." --wandb_name 'experiment_18_1e-7_lr_wd_1e-3_50_epochs'
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# wandb: Currently logged in as: tsmith-smith391 (tsmith-smith391-apziva) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path exp/wandb/wandb/ wasn't writable, using system temp directory.
# ...

# %%
# !python sweep.py --output_dir ./sweep_1 --n_epochs 5 --n_trials 50
